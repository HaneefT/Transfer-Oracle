# %%
# imports
import pandas as pd
import numpy as np
import sklearn

# %%
# load in the features of each base position
file_paths  = ['../../data/processed/players_data_processed.parquet', 
               '../../data/processed/players_data_GK.parquet', 
               '../../data/processed/players_data_DF.parquet', 
               '../../data/processed/players_data_MF.parquet', 
               '../../data/processed/players_data_FW.parquet']

df, df_gk, df_df, df_mf, df_fw = [pd.read_parquet(file) for file in file_paths]
base_positions = {'GK':df_gk, 'DF':df_df, 'MF':df_mf, 'FW':df_fw}
df_df.head()
# Out:
#     Rk            Player  Nation    Pos          Squad        Comp   Age  \
# 5    6  Yunis Abdelhamid  ma MAR     DF  Saint-Étienne  fr Ligue 1  36.0
# 8    9          Ali Abdi  tn TUN  DF,MF           Nice  fr Ligue 1  30.0
# 10  11              Abel  es ESP     DF        Osasuna  es La Liga  23.0
# 14  15             Abner  br BRA     DF           Lyon  fr Ligue 1  24.0
# 16  17       Abdel Abqar  ma MAR     DF         Alavés  es La Liga  25.0
#
#       Born  MP  Starts  ...  Fls  Fld_stats_misc  Off_stats_misc  Recov   Won  \
# 5   1987.0  16      11  ...   16             6.0             NaN     42  19.0
# 8   1993.0  25      17  ...   27            14.0             5.0     72  22.0
# 10  2000.0  35      20  ...   25            32.0             3.0    106  20.0
# 14  2000.0  19      12  ...   16             4.0             NaN     45   7.0
# 16  1999.0  29      29  ...   47            31.0             2.0     87  40.0
#
#     Lost_stats_misc  Won%   foot  numeric_wage  exposure_score
# 5                10  65.5   Left           NaN            0.30
# 8                14  61.1   Left       41923.0            0.41
# 10               17  54.1   None           NaN            0.61
# 14                9  43.8   Left       49038.0            0.32
# 16               35  53.3  Right       48077.0            0.72
#
# [5 rows x 121 columns]

# %%
# normalise numeric features for each position
from sklearn.preprocessing import StandardScaler
categorical_cols = ['Rk','Player', 'Nation', 'Pos','Squad', 'Comp', 'Age','Born','MP','Starts','Min','90s',
                    'numeric_wage', 'foot', 'W', 'D', 'L']

for pos, df_pos in base_positions.items():
    # copy all the categorical columns that exist in the dataframe
    temp_df = df_pos[[col for col in df_pos.columns if col in categorical_cols]].copy()
    df_pos = df_pos[[col for col in df_pos.columns if col not in categorical_cols]]
    display(df_pos.head())
    display(temp_df.head())
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_pos)
    base_positions[pos] = pd.concat([temp_df, pd.DataFrame(scaled_data, columns=df_pos.columns)], axis=1)
    display(base_positions[pos].head())
# Out:
#      CrdY  Cmp   Att  Cmp%  TotDist  PrgDist   1/3  Live  Dead  \
# 33    3.0  474   619  76.6    12206     8309   4.0   453   163
# 42    1.0  281   411  68.4     7681     5777   1.0   305   102
# 87    NaN  794   959  82.8    17555    11360  12.0   836   121
# 147   NaN  688   989  69.6    18224    12284  11.0   716   268
# 160   3.0  752  1027  73.2    20531    13943  10.0   728   295
#
#      FK_stats_passing_types  ...    Thr  Launch%  AvgLen    Opp   Stp  Stp%  \
# 33                       54  ...   91.0     28.0    31.2  257.0  14.0   5.4
# 42                       36  ...   51.0     37.5    33.9  143.0  20.0  14.0
# 87                       41  ...  128.0     19.7    26.6  255.0  11.0   4.3
# 147                      72  ...  119.0     34.4    32.1  394.0  15.0   3.8
# 160                     103  ...  122.0     33.2    32.9  367.0  22.0   6.0
#
#      #OPA  #OPA/90  AvgDist  exposure_score
# 33   16.0     0.84     11.7            0.50
# 42   17.0     1.27     14.2            0.35
# 87   49.0     1.76     16.0            0.73
# 147  30.0     1.19     15.0            0.66
# 160  54.0     1.74     16.0            0.82
#
# [5 rows x 78 columns]
#       Rk              Player  Nation Pos          Squad                Comp  \
# 33    34              Adrián  es ESP  GK          Betis          es La Liga
# 42    43  Julen Agirrezabala  es ESP  GK  Athletic Club          es La Liga
# 87    88             Alisson  br BRA  GK      Liverpool  eng Premier League
# 147  148     Alphonse Areola  fr FRA  GK       West Ham  eng Premier League
# 160  161   Kepa Arrizabalaga  es ESP  GK    Bournemouth  eng Premier League
#
#       Age    Born  MP  Starts   Min   90s     W    D     L   foot  \
# 33   37.0  1987.0  19      19  1710  19.0  10.0  5.0   4.0  Right
# 42   23.0  2000.0  14      14  1206  13.4   9.0  4.0   1.0   None
# 87   31.0  1992.0  28      28  2508  27.9  18.0  7.0   3.0  Right
# 147  31.0  1993.0  26      25  2260  25.1   5.0  7.0  13.0  Right
# 160  29.0  1994.0  31      31  2790  31.0  13.0  7.0  11.0  Right
#
#      numeric_wage
# 33        28077.0
# 42        51923.0
# 87       150000.0
# 147      120000.0
# 160       60000.0
#         Rk              Player  Nation Pos          Squad                Comp  \
# 33    34.0              Adrián  es ESP  GK          Betis          es La Liga
# 42    43.0  Julen Agirrezabala  es ESP  GK  Athletic Club          es La Liga
# 87    88.0             Alisson  br BRA  GK      Liverpool  eng Premier League
# 147  148.0     Alphonse Areola  fr FRA  GK       West Ham  eng Premier League
# 160  161.0   Kepa Arrizabalaga  es ESP  GK    Bournemouth  eng Premier League
#
#       Age    Born    MP  Starts  ...       Thr   Launch%    AvgLen       Opp  \
# 33   37.0  1987.0  19.0    19.0  ...  0.035277  0.665066  0.757909  0.342271
# 42   23.0  2000.0  14.0    14.0  ... -0.059606 -0.241588 -0.339193 -0.517110
# 87   31.0  1992.0  28.0    28.0  ... -0.700067 -0.249983 -0.592370 -0.047021
# 147  31.0  1993.0  26.0    25.0  ...       NaN       NaN       NaN       NaN
# 160  29.0  1994.0  31.0    31.0  ...       NaN       NaN       NaN       NaN
#
#           Stp      Stp%      #OPA   #OPA/90   AvgDist  exposure_score
# 33  -0.655211 -1.049468 -0.697674 -0.758941 -0.780636        0.542095
# 42  -0.893284 -0.857852  0.509838  0.272161  1.402145        0.586325
# 87  -1.448789 -1.892581  0.207960  0.059876  1.230947        0.099800
# 147       NaN       NaN       NaN       NaN       NaN             NaN
# 160       NaN       NaN       NaN       NaN       NaN             NaN
#
# [5 rows x 95 columns]
#     G+A  CrdY   xG  npxG  xAG  npxG+xAG  PrgC  PrgP   PrgR  G+A-PK  ...  \
# 5   NaN   2.0  0.2   0.2  0.1       0.4   4.0    22    3.0     NaN  ...
# 8   7.0   2.0  4.3   4.3  1.9       6.2  35.0    42  101.0    0.45  ...
# 10  2.0   3.0  0.5   0.5  1.0       1.6  50.0    77   92.0    0.09  ...
# 14  2.0   1.0  0.6   0.6  1.1       1.7  31.0    66   55.0    0.17  ...
# 16  1.0  13.0  0.9   0.9  0.3       1.2  16.0    79    4.0    0.04  ...
#
#     xG+/-  xG+/-90  Fls  Fld_stats_misc  Off_stats_misc  Recov   Won  \
# 5   -18.4    -1.67   16             6.0             NaN     42  19.0
# 8     8.3     0.54   27            14.0             5.0     72  22.0
# 10   -8.7    -0.38   25            32.0             3.0    106  20.0
# 14    5.8     0.48   16             4.0             NaN     45   7.0
# 16   -1.4    -0.05   47            31.0             2.0     87  40.0
#
#     Lost_stats_misc  Won%  exposure_score
# 5                10  65.5            0.30
# 8                14  61.1            0.41
# 10               17  54.1            0.61
# 14                9  43.8            0.32
# 16               35  53.3            0.72
#
# [5 rows x 107 columns]
#     Rk            Player  Nation    Pos          Squad        Comp   Age  \
# 5    6  Yunis Abdelhamid  ma MAR     DF  Saint-Étienne  fr Ligue 1  36.0
# 8    9          Ali Abdi  tn TUN  DF,MF           Nice  fr Ligue 1  30.0
# 10  11              Abel  es ESP     DF        Osasuna  es La Liga  23.0
# 14  15             Abner  br BRA     DF           Lyon  fr Ligue 1  24.0
# 16  17       Abdel Abqar  ma MAR     DF         Alavés  es La Liga  25.0
#
#       Born  MP  Starts   Min   90s   foot  numeric_wage
# 5   1987.0  16      11  1033  11.5   Left           NaN
# 8   1993.0  25      17  1393  15.5   Left       41923.0
# 10  2000.0  35      20  2074  23.0   None           NaN
# 14  2000.0  19      12  1090  12.1   Left       49038.0
# 16  1999.0  29      29  2463  27.4  Right       48077.0
#       Rk            Player  Nation    Pos          Squad        Comp   Age  \
# 5    6.0  Yunis Abdelhamid  ma MAR     DF  Saint-Étienne  fr Ligue 1  36.0
# 8    9.0          Ali Abdi  tn TUN  DF,MF           Nice  fr Ligue 1  30.0
# 10  11.0              Abel  es ESP     DF        Osasuna  es La Liga  23.0
# 14  15.0             Abner  br BRA     DF           Lyon  fr Ligue 1  24.0
# 16  17.0       Abdel Abqar  ma MAR     DF         Alavés  es La Liga  25.0
#
#       Born    MP  Starts  ...     xG+/-   xG+/-90       Fls  Fld_stats_misc  \
# 5   1987.0  16.0    11.0  ...  0.525475  0.625522 -1.048723        0.031448
# 8   1993.0  25.0    17.0  ... -0.222691 -0.336626 -0.864838       -1.013733
# 10  2000.0  35.0    20.0  ...  0.503684  0.593450 -1.048723        0.118547
# 14  2000.0  19.0    12.0  ... -0.055624 -0.047982 -0.864838       -1.013733
# 16  1999.0  29.0    29.0  ... -1.348571 -1.042202  0.238477        0.292744
#
#     Off_stats_misc     Recov       Won  Lost_stats_misc      Won%  \
# 5        -0.265072 -0.752213  1.088976         0.230279  1.152065
# 8              NaN -0.114318 -0.660836        -1.066709  0.738496
# 10             NaN -0.447133  1.088976         0.366804  1.033903
# 14       -0.265072 -1.306905 -0.294597        -0.247558  0.054841
# 16       -0.716258  0.551311 -0.620143        -0.042771 -0.941100
#
#     exposure_score
# 5        -0.540093
# 8        -1.212079
# 10       -0.488402
# 14       -0.953623
# 16        0.700497
#
# [5 rows x 121 columns]
#     Gls  Ast   G+A  G-PK  CrdY    xG  npxG  xAG  npxG+xAG  PrgC  ...  xG+/-  \
# 6   6.0  1.0   7.0   3.0   4.0   6.4   3.2  3.2       6.4   107  ...  -23.4
# 8   5.0  2.0   7.0   5.0   2.0   4.3   4.3  1.9       6.2    35  ...    8.3
# 15  7.0  2.0   9.0   6.0   4.0  10.2   8.6  1.6      10.2    34  ...    6.1
# 25  NaN  3.0   3.0   NaN   7.0   1.6   1.6  1.0       2.6    14  ...    6.6
# 29  7.0  6.0  13.0   7.0   4.0   5.5   5.5  6.0      11.5    68  ...   12.5
#
#     xG+/-90  Fls  Fld_stats_misc  Off_stats_misc  Recov   Won  \
# 6     -0.74   48              32             3.0    193  13.0
# 8      0.54   27              14             5.0     72  22.0
# 15     0.29   35              25            13.0     61  22.0
# 25     0.30   45              21             NaN    114  31.0
# 29     0.78   27              18             4.0     48   9.0
#
#     Lost_stats_misc  Won%  exposure_score
# 6                20  39.4            0.83
# 8                14  61.1            0.41
# 15               38  36.7            0.56
# 25               18  63.3            0.57
# 29               13  40.9            0.47
#
# [5 rows x 115 columns]
#     Rk             Player  Nation    Pos        Squad                Comp  \
# 6    7      Himad Abdelli  dz ALG  MF,FW       Angers          fr Ligue 1
# 8    9           Ali Abdi  tn TUN  DF,MF         Nice          fr Ligue 1
# 15  16  Zakaria Aboukhlal  ma MAR  MF,FW     Toulouse          fr Ligue 1
# 25  26        Tyler Adams  us USA     MF  Bournemouth  eng Premier League
# 29  30      Karim Adeyemi  de GER  FW,MF     Dortmund       de Bundesliga
#
#      Age    Born  MP  Starts   Min   90s   foot  numeric_wage
# 6   24.0  1999.0  32      32  2842  31.6   None       12308.0
# 8   30.0  1993.0  25      17  1393  15.5   Left       41923.0
# 15  24.0  2000.0  26      22  1901  21.1   Left       39231.0
# 25  25.0  1999.0  28      21  1965  21.8  Right       60000.0
# 29  22.0  2002.0  25      17  1433  15.9   Left       96154.0
#       Rk             Player  Nation    Pos        Squad                Comp  \
# 6    7.0      Himad Abdelli  dz ALG  MF,FW       Angers          fr Ligue 1
# 8    9.0           Ali Abdi  tn TUN  DF,MF         Nice          fr Ligue 1
# 15  16.0  Zakaria Aboukhlal  ma MAR  MF,FW     Toulouse          fr Ligue 1
# 25  26.0        Tyler Adams  us USA     MF  Bournemouth  eng Premier League
# 29  30.0      Karim Adeyemi  de GER  FW,MF     Dortmund       de Bundesliga
#
#      Age    Born    MP  Starts  ...     xG+/-   xG+/-90       Fls  \
# 6   24.0  1999.0  32.0    32.0  ...  0.440169  0.706831 -1.327083
# 8   30.0  1993.0  25.0    17.0  ... -0.498473 -0.430006  1.714149
# 15  24.0  2000.0  26.0    22.0  ... -0.388044 -0.363133  0.117502
# 25  25.0  1999.0  28.0    21.0  ...  0.771454  0.940886  0.193533
# 29  22.0  2002.0  25.0    17.0  ... -0.159300 -0.112360  1.866211
#
#     Fld_stats_misc  Off_stats_misc     Recov       Won  Lost_stats_misc  \
# 6        -0.500836             NaN -0.423503 -0.863757        -0.496694
# 8        -1.378585       -0.618083  1.054333  1.261619         0.980393
# 15        0.627699       -0.618083 -0.122927 -0.863757        -0.558239
# 25       -0.688925             NaN -0.523696  0.055325        -0.742875
# 29        1.505449       -0.355013  1.079381  2.238144         1.842027
#
#         Won%  exposure_score
# 6  -1.407469       -1.157708
# 8   0.627003        0.295327
# 15 -1.318368        0.071783
# 25  1.547713       -0.263533
# 29  0.701254        1.189503
#
# [5 rows x 129 columns]
#     Gls  Ast   G+A  G-PK  CrdY    xG  npxG  xAG  npxG+xAG  PrgC  ...  xG+/-  \
# 6   6.0  1.0   7.0   3.0   4.0   6.4   3.2  3.2       6.4   107  ...  -23.4
# 13  9.0  2.0  11.0   8.0   3.0   8.5   7.7  3.8      11.5    75  ...  -12.6
# 15  7.0  2.0   9.0   6.0   4.0  10.2   8.6  1.6      10.2    34  ...    6.1
# 18  3.0  4.0   7.0   2.0   1.0   7.1   5.4  2.2       7.6     8  ...   11.3
# 23  3.0  1.0   4.0   3.0   2.0   4.3   4.3  1.0       5.3    11  ...  -10.8
#
#     xG+/-90  Fls  Fld_stats_misc  Off_stats_misc  Recov   Won  \
# 6     -0.74   48              32             3.0    193  13.0
# 13    -0.41   34              53             5.0     83  64.0
# 15     0.29   35              25            13.0     61  22.0
# 18     0.86   23              12             7.0     12  36.0
# 23    -0.90   17               8            16.0     24  28.0
#
#     Lost_stats_misc  Won%  exposure_score
# 6                20  39.4            0.83
# 13               76  45.7            0.81
# 15               38  36.7            0.56
# 18               33  52.2            0.35
# 23               27  50.9            0.31
#
# [5 rows x 112 columns]
#     Rk             Player   Nation    Pos        Squad        Comp   Age  \
# 6    7      Himad Abdelli   dz ALG  MF,FW       Angers  fr Ligue 1  24.0
# 13  14     Matthis Abline   fr FRA     FW       Nantes  fr Ligue 1  21.0
# 15  16  Zakaria Aboukhlal   ma MAR  MF,FW     Toulouse  fr Ligue 1  24.0
# 18  19      Tammy Abraham  eng ENG     FW        Milan  it Serie A  26.0
# 23  24         Akor Adams   ng NGA     FW  Montpellier  fr Ligue 1  24.0
#
#       Born  MP  Starts   Min   90s   foot  numeric_wage
# 6   1999.0  32      32  2842  31.6   None       12308.0
# 13  2003.0  34      33  2768  30.8   None       22692.0
# 15  2000.0  26      22  1901  21.1   Left       39231.0
# 18  1997.0  28      12  1183  13.1  Right           NaN
# 23  2000.0  15      13  1075  11.9   None       36154.0
#       Rk             Player   Nation    Pos        Squad        Comp   Age  \
# 6    7.0      Himad Abdelli   dz ALG  MF,FW       Angers  fr Ligue 1  24.0
# 13  14.0     Matthis Abline   fr FRA     FW       Nantes  fr Ligue 1  21.0
# 15  16.0  Zakaria Aboukhlal   ma MAR  MF,FW     Toulouse  fr Ligue 1  24.0
# 18  19.0      Tammy Abraham  eng ENG     FW        Milan  it Serie A  26.0
# 23  24.0         Akor Adams   ng NGA     FW  Montpellier  fr Ligue 1  24.0
#
#       Born    MP  Starts  ...     xG+/-   xG+/-90       Fls  Fld_stats_misc  \
# 6   1999.0  32.0    32.0  ...  0.292600  0.381892  1.062612       -0.476652
# 13  2003.0  34.0    33.0  ...  0.276975  0.429728 -0.754145        0.090280
# 15  2000.0  26.0    22.0  ... -0.973073 -1.005344 -0.517176       -0.287675
# 18  1997.0  28.0    12.0  ... -0.887132 -0.973454  0.193728       -0.098697
# 23  2000.0  15.0    13.0  ...  0.308226  0.477563 -0.754145       -0.161690
#
#     Off_stats_misc     Recov       Won  Lost_stats_misc      Won%  \
# 6         1.403645 -0.535204  1.042764         2.705713 -0.484001
# 13       -0.287910 -1.018032 -0.853096        -0.756990 -1.731795
# 15        0.327201  0.623583 -0.587675        -0.388617 -0.769444
# 18       -0.749243  0.076378 -0.511841        -0.572803 -0.010981
# 23       -1.056798  0.140755 -0.777261        -0.756990 -1.022265
#
#     exposure_score
# 6        -0.271926
# 13       -0.844401
# 15       -0.214678
# 18       -0.386421
# 23       -0.844401
#
# [5 rows x 126 columns]
